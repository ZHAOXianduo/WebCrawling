# %%
### 导入所需的数据库
import time
import requests
import json
import jsonpath
import pymongo
import pandas as pd
import urllib
import datetime
import numpy as np
from threading import Thread
from urllib.parse import urlencode

# %%
### 导入股票列表
Stocks = pd.read_excel(r'I:\个股数据\Total_Stock.xlsx') # 获取股票代码
# 参数项
## 概念板块初始和目前页面数
i_page_i = 5

# %% [markdown]
# ## 概念主页数据抓取

# %%
# 概念主页爬虫(多线程抓取)

## 设置请求地址
url_1 = 'http://63.push2.eastmoney.com/api/qt/clist/get?'
## 设置请求头
headers_1 = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36',
    'Cookie': 'qgqp_b_id=d4c7d95b9a3fea432b6afb4394d1e7cb; em_hq_fls=js; st_si=11660912221455; cowminicookie=true; intellpositionL=1215.35px; st_asi=delete; HAList=ty-90-BK0918-%u7279%u9AD8%u538B%2Cty-90-BK0958-%u865A%u62DF%u7535%u5382%2Ca-sz-301179-N%u6CFD%u5B87%2Cf-0-000012-%u56FD%u503A%u6307%u6570; cowCookie=true; intellpositionT=655px; st_pvi=54890317298070; st_sp=2021-02-13%2023%3A08%3A33; st_inirUrl=https%3A%2F%2Fwww.sogou.com%2Flink; st_sn=38; st_psi=20211216140000383-113200313002-1170878720'
}
## 设置记录列表
F12_ = []
F14_ = []
F2_  = []
F4_  = []
F3_  = []
F7_  = []
F20_ = []
F21_ = []
F8_  = []
F104_= []
F105_= []
F10_ = []
F17_ = []
F18_ = []
F15_ = []
F16_ = []
F62_ = []
F128_= []
F140_= []
F136_= []
F207_= []
F208_= []
F222_= []
## 设置特征列表
Index_c = ['板块编码','板块名称','板块最新价','板块涨跌额','板块涨跌幅','板块振幅','板块总市值','板块流通市值','板块换手率','上涨家数','下跌家数量','板块量比','板块今开','板块昨收','板块最高','板块最低','板块主力净流入','领涨股票','领涨股票编码','领涨股票涨幅','领跌股票','领跌股票编码','领跌股票涨幅']
def thread():   
    def get_params(k):
        params_M_c = {
        'cb': 'jQuery1124018456954517801738_1639634362993',
        'pn': str(k+1), #修改pn能够得到下一页
        'pz': '20',
        'po': '1',
        'np': '1',
        'ut': 'bd1d9ddb04089700cf9c27f6f7426281',
        'fltt': '2',
        'invt': '2',
        'fid': 'f3',
        'fs': 'm:90 t:3 f:!50',
        'fields': 'f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f12,f13,f14,f15,f16,f17,f18,f20,f21,f23,f24,f25,f26,f22,f33,f11,f62,f128,f136,f115,f152,f124,f107,f104,f105,f140,f141,f207,f208,f209,f222',
        '_': '1639634363007'
        }
        response = requests.get(url_1 + urlencode(params_M_c), params=params_M_c,verify=False,headers = headers_1)
        Length = len(params_M_c['cb'])
        json_ = json.loads('['+response.text[Length+1:-2]+']')
        concept_ = json_[0]['data']['diff']
        for i in range(len(concept_)):
            F12_.append(concept_[i]['f12'])
            F14_.append(concept_[i]['f14'])
            F2_.append(concept_[i]['f2'])
            F4_.append(concept_[i]['f4'])
            F3_.append(concept_[i]['f3'])
            F7_.append(concept_[i]['f7'])
            F20_.append(concept_[i]['f20'])
            F21_.append(concept_[i]['f21'])
            F8_.append(concept_[i]['f8'])
            F104_.append(concept_[i]['f104'])
            F105_.append(concept_[i]['f105'])
            F10_.append(concept_[i]['f10'])
            F17_.append(concept_[i]['f17'])
            F18_.append(concept_[i]['f18'])
            F15_.append(concept_[i]['f15'])
            F16_.append(concept_[i]['f16'])
            F62_.append(concept_[i]['f62'])
            F128_.append(concept_[i]['f128'])
            F140_.append(concept_[i]['f140'])
            F136_.append(concept_[i]['f136'])
            F207_.append(concept_[i]['f207'])
            F208_.append(concept_[i]['f208'])
            F222_.append(concept_[i]['f222'])
    print(u'多线程抓取')                                                                                        
    ts = [Thread(target=get_params, args=(k,)) for k in range(i_page_c)]                                                 
    starttime= time.time()                                                                                 
    for t in ts:                                                                                           
        t.start()                                                                                          
    for t in ts:                                                                                           
        t.join()                                                                                           
    endtime=time.time()                                                                                    
    print('数据爬取总耗时：',endtime-starttime)
thread()
### 构建数据
Data = pd.DataFrame(np.transpose([F12_,F14_,F2_,F4_,F3_,F7_,F20_,F21_,F8_,F104_,F105_,F10_,F17_,F18_,F15_,F16_,F62_,F128_,F140_,F136_,F207_,F208_,F222_]),columns = Index_c)
#Data.to_excel(r'C:\Users\NHT\Desktop\东方财富板块数据'+str(datetime.datetime.now())[:10]+'.xlsx')
print('Finish!')
# Out:
# 多线程抓取
# 数据爬取总耗时： 3.6134963035583496
# Finish!

# %% [markdown]
# ## 抓取概念板块中个股今日资金流动

# %%
# 概念子页爬虫(顺序爬取)--今日排行
## 设置请求地址
url_D = 'http://push2.eastmoney.com/api/qt/clist/get?'
## 设置请求头
headers_1 = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36',
    'Cookie': 'qgqp_b_id=d4c7d95b9a3fea432b6afb4394d1e7cb; em_hq_fls=js; st_si=11660912221455; cowminicookie=true; intellpositionL=1215.35px; st_asi=delete; HAList=ty-90-BK0918-%u7279%u9AD8%u538B%2Cty-90-BK0958-%u865A%u62DF%u7535%u5382%2Ca-sz-301179-N%u6CFD%u5B87%2Cf-0-000012-%u56FD%u503A%u6307%u6570; cowCookie=true; intellpositionT=655px; st_pvi=54890317298070; st_sp=2021-02-13%2023%3A08%3A33; st_inirUrl=https%3A%2F%2Fwww.sogou.com%2Flink; st_sn=38; st_psi=20211216140000383-113200313002-1170878720'
}
## 设置特征列表
Index_c = ['代码','名称','最新价','涨跌幅','主力净流入额','主力净流入占比','超大单净流入额','超大单净流入占比','大单净流入额',
          '大单净流入额','大单净流入占比','中单净流入占比','小单净流入额','小单净流入占比']
starttime= time.time() #开始计时
## 设置传递参数
for k in range(len(Data)): 
    starttime_= time.time() #开始计时
    ## 设置记录列表
    F12_ = []
    F14_ = []
    F2_  = []
    F3_  = []
    F62_ = []
    F184_= []
    F66_ = []
    F69_ = []
    F72_ = []
    F75_ = []
    F78_ = []
    F81_ = []
    F84_ = []
    F87_ = []
    print('Concept:',Data['板块名称'][k])
    params_M_c = {
        'cb': 'jQuery112306861266349057402_1639874233876',
        'fid': 'f62', #涉及抽取的表格
        'po': '1',
        'pz': '50',
        'pn': '1',
        'np': '1',
        'fltt': '2',
        'invt': '2',
        'ut': 'b2884a393a59ad64002292a3e90d46a5',
        'fs': 'b:'+str(Data['板块编码'][k]), #涉及抽取的行业/概念
        'fields': 'f12,f14,f2,f3,f62,f184,f66,f69,f72,f75,f78,f81,f84,f87,f204,f205,f124,f1,f13' #涉及抽取的表格的数据
    }
    try:
        response = requests.get(url_D + urlencode(params_M_c), params=params_M_c,verify=False,headers = headers_1)
    except:
        print('爬取不到数据......')
    Length = len(params_M_c['cb'])
    json_ = json.loads('['+response.text[Length+1:-2]+']')
    concept_ = json_[0]['data']['diff']
    for i in range(len(concept_)):
        F12_.append(concept_[i]['f12'])
        F14_.append(concept_[i]['f14'])
        F2_.append(concept_[i]['f2'])
        F3_.append(concept_[i]['f3'])
        F62_.append(concept_[i]['f62'])
        F184_.append(concept_[i]['f184'])
        F66_.append(concept_[i]['f66'])
        F69_.append(concept_[i]['f69'])
        F72_.append(concept_[i]['f72'])
        F75_.append(concept_[i]['f75'])
        F78_.append(concept_[i]['f78'])
        F81_.append(concept_[i]['f81'])
        F84_.append(concept_[i]['f84'])
        F87_.append(concept_[i]['f87'])
    Data_ = pd.DataFrame(np.transpose([F12_,F14_,F2_,F3_,F62_,F184_,F66_,F69_,F72_,F75_,F78_,F81_,F84_,F87_]),columns = Index_c)
    Data_.to_excel(r'C:\Users\NHT\Desktop\东方财富概念清单'+'\\'+str(datetime.datetime.now())[:10]+str(Data['板块编码'][k])+'-今日排行.xlsx')
    time.sleep(0.1)
    endtime_=time.time() #结束计时                                                                      
    During_= endtime_-starttime_ #计算总耗时
    print(During_)
endtime=time.time() #结束计时                                                                      
During= endtime-starttime #计算总耗时
print('数据爬取总耗时：',During,'秒')
### 构建数据
print('Finish!')
# Out:
# Concept: 海绵城市
# 0.889552116394043
# Concept: 装配建筑
# 0.27988123893737793
# Concept: 参股券商
# 0.2793560028076172
# Concept: AB股
# 0.5273046493530273
# Concept: 乡村振兴
# 1.3061349391937256
# Concept: 一带一路
# 0.251697301864624
# Concept: 维生素
# 0.26522159576416016
# Concept: 水产养殖
# 0.2679471969604492
# Concept: ST股
# 3.261082410812378
# Concept: 网红直播
# 0.5376448631286621
# Concept: 纾困概念
# 0.2597527503967285
# Concept: 参股保险
# 0.2874441146850586
# Concept: B股
# 0.25969791412353516
# Concept: 碳交易
# 0.28368115425109863
# Concept: 成渝特区
# 0.2570827007293701
# Concept: 基因测序
# 0.25436830520629883
# Concept: 黄金概念
# 0.25665926933288574
# Concept: 海工装备
# 0.27374982833862305
# Concept: 参股银行
# 0.28737568855285645
# Concept: 东北振兴
# 9.260928392410278
# Concept: 天然气
# 0.27643394470214844
# Concept: 充电桩
# 0.25571370124816895
# Concept: 农业种植
# 0.5361001491546631
# Concept: 抖音小店
# 0.26430463790893555
# Concept: 可燃冰
# 0.5203797817230225
# Concept: 滨海新区
# 0.28932952880859375
# Concept: 手游概念
# 0.3078422546386719
# Concept: 水利建设
# 0.3041973114013672
# Concept: 电子竞技
# 0.2666807174682617
# Concept: 基本金属
# 0.2968709468841553
# Concept: 壳资源
# 3.5606420040130615
# Concept: 超导概念
# 0.2374880313873291
# Concept: ETC
# 0.24797940254211426
# Concept: 网络游戏
# 0.27743959426879883
# Concept: 远程办公
# 3.252413511276245
# Concept: RCEP概念
# 3.246312141418457
# Concept: 数字货币
# 0.2656114101409912
# Concept: 页岩气
# 0.2498941421508789
# Concept: 沪企改革
# 0.25018787384033203
# Concept: 字节概念
# 0.3071119785308838
# Concept: 转债标的
# 3.260542631149292
# Concept: 口罩
# 0.27857232093811035
# Concept: 鸡肉概念
# 0.27128171920776367
# Concept: 医疗美容
# 3.252974033355713
# Concept: 辅助生殖
# 0.248948335647583
# Concept: 网络安全
# 0.25917649269104004
# Concept: UWB概念
# 0.5584375858306885
# Concept: 草甘膦
# 0.2623438835144043
# Concept: 湖北自贸
# 0.2781813144683838
# Concept: MicroLED
# 0.2534184455871582
# Concept: 婴童概念
# 0.26010942459106445
# Concept: 汽车拆解
# 3.24015212059021
# Concept: 边缘计算
# 0.6041200160980225
# Concept: 军工
# 3.2573864459991455
# Concept: 新零售
# 9.254711627960205
# Concept: 乳业
# 3.258232831954956
# Concept: 在线教育
# 0.298053503036499
# Concept: 太阳能
# 0.27828097343444824
# Concept: 单抗概念
# 0.2663567066192627
# Concept: 物联网
# 0.27622246742248535
# Concept: 核污染防治
# 0.25992822647094727
# Concept: 快递概念
# 0.24645471572875977
# Concept: 地摊经济
# 0.25133705139160156
# Concept: CAR-T细胞疗法
# 0.27426695823669434
# Concept: 养老概念
# 0.5259029865264893
# Concept: 免税概念
# 0.2714223861694336
# Concept: 标准普尔
# 0.3799557685852051
# Concept: 低碳冶金
# 0.26563453674316406
# Concept: 精准医疗
# 0.28457164764404297
# Concept: 中证500
# 3.2850005626678467
# Concept: IPO受益
# 0.9383449554443359
# Concept: 大数据
# 4.7266905307769775
# Concept: 调味品概念
# 3.2598612308502197
# Concept: 煤化工
# 0.2767155170440674
# Concept: 病毒防治
# 0.2562873363494873
# Concept: 发电机概念
# 1.2758193016052246
# Concept: 环氧丙烷
# 0.26157069206237793
# Concept: 氢能源
# 0.2733323574066162
# Concept: 中超概念
# 3.260824680328369
# Concept: 青蒿素
# 3.548112154006958
# Concept: 参股期货
# 3.281219720840454
# Concept: 内贸流通
# 0.27831339836120605
# Concept: 体外诊断
# 0.29386115074157715
# Concept: 上海自贸
# 0.8707671165466309
# Concept: 超级真菌
# 0.24335265159606934
# Concept: 区块链
# 9.531837463378906
# Concept: 健康中国
# 0.27486515045166016
# Concept: 百度概念
# 3.2948687076568604
# Concept: 流感
# 0.2939307689666748
# Concept: 证金持股
# 0.5404911041259766
# Concept: 京东金融
# 0.26238059997558594
# Concept: 数字孪生
# 0.863025426864624
# Concept: 互联金融
# 0.27101612091064453
# Concept: 贬值受益
# 0.34298276901245117
# Concept: 人造肉
# 1.2671763896942139
# Concept: 肝素概念
# 0.2551898956298828
# Concept: 电子烟
# 0.2800602912902832
# Concept: 被动元件
# 0.2905755043029785
# Concept: 数据安全
# 0.2812378406524658
# Concept: 第三代半导体
# 0.2764933109283447
# Concept: PCB
# 0.5623817443847656
# Concept: 纳米银
# 0.279766321182251
# Concept: 半导体概念
# 3.343256950378418
# Concept: MLCC
# 0.27817749977111816
# Concept: 碳化硅
# 3.5809123516082764
# Concept: PVDF概念
# 0.2711601257324219
# Concept: 碳基材料
# 0.3210029602050781
# Concept: 宁组合
# 0.3417093753814697
# Concept: 全息技术
# 0.29729270935058594
# Concept: 空间站概念
# 0.29715871810913086
# Concept: 光刻胶
# 0.28812170028686523
# Concept: 稀土永磁
# 0.3094964027404785
# Concept: HIT电池
# 0.2897310256958008
# Concept: 工业母机
# 0.2694988250732422
# Concept: 蓝宝石
# 0.30090999603271484
# Concept: 中芯概念
# 0.3381352424621582
# Concept: 培育钻石
# 0.5152130126953125
# Concept: 汽车芯片
# 0.26381564140319824
# Concept: 氦气概念
# 0.2647390365600586
# Concept: C2M概念
# 0.26636362075805664
# Concept: 猪肉概念
# 0.27512025833129883
# Concept: 虚拟电厂
# 0.2634754180908203
# Concept: 北交所概念
# 0.24766159057617188
# Concept: 智慧城市
# 0.5249354839324951
# Concept: 数据中心
# 0.5815596580505371
# Concept: 快手概念
# 0.24719738960266113
# Concept: 节能环保
# 1.3327229022979736
# Concept: 长江三角
# 0.771761417388916
# Concept: 通用航空
# 0.39847278594970703
# Concept: 航母概念
# 0.6009190082550049
# Concept: 蚂蚁概念
# 0.25413966178894043
# Concept: 医废处理
# 0.2805304527282715
# Concept: 3D玻璃
# 0.26405835151672363
# Concept: 铁路基建
# 0.4902839660644531
# Concept: 进口博览
# 3.936474084854126
# Concept: 阿兹海默
# 4.342859268188477
# Concept: 地塞米松
# 3.286409854888916
# Concept: 生物识别
# 0.6798663139343262
# Concept: 免疫治疗
# 0.30422306060791016
# Concept: AH股
# 0.3325648307800293
# Concept: 互联医疗
# 0.279998779296875
# Concept: 退税商店
# 0.266024112701416
# Concept: 工程机械概念
# 0.278195858001709
# Concept: 疫苗冷链
# 0.5734775066375732
# Concept: 万达概念
# 0.29571056365966797
# Concept: EDA概念
# 1.4119782447814941
# Concept: 垃圾分类
# 3.255760908126831
# Concept: 股权转让
# 0.5517375469207764
# Concept: 预亏预减
# 0.28594160079956055
# Concept: 冷链物流
# 3.3217926025390625
# Concept: 中字头
# 0.2759108543395996
# Concept: 换电概念
# 0.24709057807922363
# Concept: 粤港自贸
# 3.3187382221221924
# Concept: 参股新三板
# 0.5658094882965088
# Concept: 燃料电池
# 3.2690560817718506
# Concept: 生态农业
# 9.283058881759644
# Concept: 储能
# 0.42645859718322754
# Concept: 创投
# 0.33272337913513184
# Concept: 影视概念
# 0.31480860710144043
# Concept: 雄安新区
# 0.2840151786804199
# Concept: 土地流转
# 1.2845404148101807
# Concept: 商汤概念
# 1.3166632652282715
# Concept: 智能电视
# 0.3535642623901367
# Concept: PPP模式
# 0.3488888740539551
# Concept: 风能
# 0.29173946380615234
# Concept: 海洋经济
# 0.5287721157073975
# Concept: 油气设服
# 5.564502239227295
# Concept: 彩票概念
# 0.3596925735473633
# Concept: 北京冬奥
# 0.3074829578399658
# Concept: 债转股
# 0.2523009777069092
# Concept: 工业大麻
# 0.2811422348022461
# Concept: 广电
# 0.24999356269836426
# Concept: 新能源
# 0.28550195693969727
# Concept: 独家药品
# 3.989995241165161
# Concept: 拼多多概念
# 0.3537311553955078
# Concept: 体育产业
# 0.25736021995544434
# Concept: 国企改革
# 0.282651424407959
# Concept: 元宇宙概念
# 0.2841510772705078
# Concept: 华为昇腾
# 0.2744314670562744
# Concept: 昨日连板
# 0.300365686416626
# Concept: 昨日涨停
# 0.5757584571838379
# Concept: 转基因
# 0.5217015743255615
# Concept: 电子车牌
# 0.5804750919342041
# Concept: 云游戏
# 3.2752835750579834
# Concept: 特高压
# 0.5843765735626221
# Concept: NFT概念
# 1.380751132965088
# Concept: 人脑工程
# 0.2698636054992676
# Concept: RCS概念
# 0.2676424980163574
# Concept: 京津冀
# 3.8633010387420654
# Concept: 赛马概念
# 0.3378629684448242
# Concept: REITs概念
# 0.2805776596069336
# Concept: 绿色电力
# 0.2992849349975586
# Concept: 核能核电
# 0.2733957767486572
# Concept: 长寿药
# 0.2599508762359619
# Concept: 智能电网
# 0.2800922393798828
# Concept: 油价相关
# 0.28213953971862793
# Concept: 地热能
# 9.268213748931885
# Concept: 抽水蓄能
# 0.266939640045166
# Concept: 租售同权
# 0.2818331718444824
# 数据爬取总耗时： 388.2109100818634 秒
# Finish!

# %% [markdown]
# ## 抓取概念板块中个股5日资金流动

# %%
# 概念子页爬虫(顺序爬取)--5日排行
## 设置请求地址
url_D = 'http://push2.eastmoney.com/api/qt/clist/get?'
## 设置请求头
headers_1 = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36',
    'Cookie': 'qgqp_b_id=d4c7d95b9a3fea432b6afb4394d1e7cb; em_hq_fls=js; st_si=11660912221455; cowminicookie=true; intellpositionL=1215.35px; st_asi=delete; HAList=ty-90-BK0918-%u7279%u9AD8%u538B%2Cty-90-BK0958-%u865A%u62DF%u7535%u5382%2Ca-sz-301179-N%u6CFD%u5B87%2Cf-0-000012-%u56FD%u503A%u6307%u6570; cowCookie=true; intellpositionT=655px; st_pvi=54890317298070; st_sp=2021-02-13%2023%3A08%3A33; st_inirUrl=https%3A%2F%2Fwww.sogou.com%2Flink; st_sn=38; st_psi=20211216140000383-113200313002-1170878720'
}
## 设置特征列表
Index_c = ['代码','名称','最新价','涨跌幅','主力净流入额','主力净流入占比','超大单净流入额','超大单净流入占比','大单净流入额',
          '大单净流入额','大单净流入占比','中单净流入占比','小单净流入额','小单净流入占比']
starttime= time.time() #开始计时
## 设置传递参数
for k in range(len(Data)): 
    starttime_= time.time() #开始计时
    ## 设置记录列表
    F12_ = []
    F14_ = []
    F2_  = []
    F109_= []
    F164_= []
    F165_= []
    F166_= []
    F167_= []
    F168_= []
    F169_= []
    F170_= []
    F171_= []
    F172_= []
    F173_= []
    print('Concept:',Data['板块名称'][k])
    params_M_c = {
        'cb': 'jQuery112306861266349057402_1639874233876',
        'fid': 'f164', #涉及抽取的表格
        'po': '1',
        'pz': '50',
        'pn': '1',
        'np': '1',
        'fltt': '2',
        'invt': '2',
        'ut': 'b2884a393a59ad64002292a3e90d46a5',
        'fs': 'b:'+str(Data['板块编码'][k]), #涉及抽取的行业/概念
        'fields': 'f12,f14,f2,f109,f164,f165,f166,f167,f168,f169,f170,f171,f172,f173,f257,f258,f124,f1,f13' #涉及抽取的表格的数据
    }
    try:
        response = requests.get(url_D + urlencode(params_M_c), params=params_M_c,verify=False,headers = headers_1)
    except:
        print('爬取不到数据......')
    Length = len(params_M_c['cb'])
    json_ = json.loads('['+response.text[Length+1:-2]+']')
    concept_ = json_[0]['data']['diff']
    for i in range(len(concept_)):
        F12_.append(concept_[i]['f12'])
        F14_.append(concept_[i]['f14'])
        F2_.append(concept_[i]['f2'])
        F109_.append(concept_[i]['f109'])
        F164_.append(concept_[i]['f164'])
        F165_.append(concept_[i]['f165'])
        F166_.append(concept_[i]['f166'])
        F167_.append(concept_[i]['f167'])
        F168_.append(concept_[i]['f168'])
        F169_.append(concept_[i]['f169'])
        F170_.append(concept_[i]['f170'])
        F171_.append(concept_[i]['f171'])
        F172_.append(concept_[i]['f172'])
        F173_.append(concept_[i]['f173'])
    Data_ = pd.DataFrame(np.transpose([F12_,F14_,F2_,F109_,F164_,F165_,F166_,F167_,F168_,F169_,F170_,F171_,F172_,F173_]),columns = Index_c)
    Data_.to_excel(r'C:\Users\NHT\Desktop\东方财富概念清单'+'\\'+str(datetime.datetime.now())[:10]+str(Data['板块编码'][k])+'-5日排行.xlsx')
    time.sleep(0.1)
    endtime_=time.time() #结束计时                                                                      
    During_= endtime_-starttime_ #计算总耗时
    print(During_)
endtime=time.time() #结束计时                                                                      
During= endtime-starttime #计算总耗时
print('数据爬取总耗时：',During,'秒')
### 构建数据
print('Finish!')
# Out:
# Concept: 海绵城市
# 0.28310155868530273
# Concept: 装配建筑
# 0.2783701419830322
# Concept: 参股券商
# 0.2810211181640625
# Concept: AB股
# 0.2775692939758301
# Concept: 乡村振兴
# 0.5787491798400879
# Concept: 一带一路
# 0.561119556427002
# Concept: 维生素
# 0.5190072059631348
# Concept: 水产养殖
# 0.24174261093139648
# Concept: ST股
# 0.2557692527770996
# Concept: 网红直播
# 0.3470726013183594
# Concept: 纾困概念
# 0.26137757301330566
# Concept: 参股保险
# 0.27338480949401855
# Concept: B股
# 0.27426624298095703
# Concept: 碳交易
# 0.27352023124694824
# Concept: 成渝特区
# 0.2563323974609375
# Concept: 基因测序
# 0.2741525173187256
# Concept: 黄金概念
# 0.25091028213500977
# Concept: 海工装备
# 0.2848076820373535
# Concept: 参股银行
# 0.2830967903137207
# Concept: 东北振兴
# 0.2557847499847412
# Concept: 天然气
# 0.3500633239746094
# Concept: 充电桩
# Concept: 生态农业
# 0.23641109466552734
# Concept: 储能
# 0.2610588073730469
# Concept: 创投
# 0.24601173400878906
# Concept: 影视概念
# 0.23607587814331055
# Concept: 雄安新区
# 0.25338101387023926
# Concept: 土地流转
# 0.26105761528015137
# Concept: 商汤概念
# 0.24266743659973145
# Concept: 智能电视
# 0.24014592170715332
# Concept: PPP模式
# 0.23853754997253418
# Concept: 风能
# 0.22859764099121094
# Concept: 海洋经济
# 0.27936887741088867
# Concept: 油气设服
# 0.2346351146697998
# Concept: 彩票概念
# 0.2664942741394043
# Concept: 北京冬奥
# 0.22978806495666504
# Concept: 债转股
# 0.26815080642700195
# Concept: 工业大麻
# 0.2610452175140381
# Concept: 广电
# 0.27138543128967285
# Concept: 新能源
# 0.2294292449951172
# Concept: 独家药品
# 0.2271888256072998
# Concept: 拼多多概念
# 0.21687698364257812
# Concept: 体育产业
# 0.24650931358337402
# Concept: 国企改革
# 0.24387216567993164
# Concept: 元宇宙概念
# 0.23196816444396973
# Concept: 华为昇腾
# 0.23863005638122559
# Concept: 昨日连板
# 0.22026324272155762
# Concept: 昨日涨停
# 0.2453906536102295
# Concept: 转基因
# 0.2403120994567871
# Concept: 电子车牌
# 0.2343745231628418
# Concept: 云游戏
# 0.23337936401367188
# Concept: 特高压
# 0.2611117362976074
# Concept: NFT概念
# 3.2292613983154297
# Concept: 人脑工程
# 0.20961737632751465
# Concept: RCS概念
# 0.22592878341674805
# Concept: 京津冀
# 0.26453208923339844
# Concept: 赛马概念
# 0.5051507949829102
# Concept: REITs概念
# 0.22112703323364258
# Concept: 绿色电力
# 0.26340556144714355
# Concept: 核能核电
# 0.5194878578186035
# Concept: 长寿药
# 3.229705333709717
# Concept: 智能电网
# 0.23598909378051758
# Concept: 油价相关
# 0.24114036560058594
# Concept: 地热能
# 0.22774004936218262
# Concept: 抽水蓄能
# 0.22082924842834473
# Concept: 租售同权
# 0.21967482566833496
# 数据爬取总耗时： 143.28171467781067 秒
# Finish!

# %% [markdown]
# ## 抓取概念板块中个股10日资金流动

# %%
# 概念子页爬虫(顺序爬取)--10日排行
## 设置请求地址
url_D = 'http://push2.eastmoney.com/api/qt/clist/get?'
## 设置请求头
headers_1 = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36',
    'Cookie': 'qgqp_b_id=d4c7d95b9a3fea432b6afb4394d1e7cb; em_hq_fls=js; st_si=11660912221455; cowminicookie=true; intellpositionL=1215.35px; st_asi=delete; HAList=ty-90-BK0918-%u7279%u9AD8%u538B%2Cty-90-BK0958-%u865A%u62DF%u7535%u5382%2Ca-sz-301179-N%u6CFD%u5B87%2Cf-0-000012-%u56FD%u503A%u6307%u6570; cowCookie=true; intellpositionT=655px; st_pvi=54890317298070; st_sp=2021-02-13%2023%3A08%3A33; st_inirUrl=https%3A%2F%2Fwww.sogou.com%2Flink; st_sn=38; st_psi=20211216140000383-113200313002-1170878720'
}
## 设置特征列表
Index_c = ['代码','名称','最新价','涨跌幅','主力净流入额','主力净流入占比','超大单净流入额','超大单净流入占比','大单净流入额',
          '大单净流入额','大单净流入占比','中单净流入占比','小单净流入额','小单净流入占比']
starttime= time.time() #开始计时
## 设置传递参数
for k in range(len(Data)): 
    starttime_= time.time() #开始计时
    ## 设置记录列表
    F12_ = []
    F14_ = []
    F2_  = []
    F160_= []
    F174_= []
    F175_= []
    F176_= []
    F177_= []
    F178_= []
    F179_= []
    F180_= []
    F181_= []
    F182_= []
    F183_= []
    print('Concept:',Data['板块名称'][k])
    params_M_c = {
        'cb': 'jQuery112306861266349057402_1639874233876',
        'fid': 'f174', #涉及抽取的表格
        'po': '1',
        'pz': '50',
        'pn': '1',
        'np': '1',
        'fltt': '2',
        'invt': '2',
        'ut': 'b2884a393a59ad64002292a3e90d46a5',
        'fs': 'b:'+str(Data['板块编码'][k]), #涉及抽取的行业/概念
        'fields': 'f12,f14,f2,f160,f174,f175,f176,f177,f178,f179,f180,f181,f182,f183,f260,f261,f124,f1,f13' #涉及抽取的表格的数据
    }
    try:
        response = requests.get(url_D + urlencode(params_M_c), params=params_M_c,verify=False,headers = headers_1)
    except:
        print('爬取不到数据......')
    Length = len(params_M_c['cb'])
    json_ = json.loads('['+response.text[Length+1:-2]+']')
    concept_ = json_[0]['data']['diff']
    for i in range(len(concept_)):
        F12_.append(concept_[i]['f12'])
        F14_.append(concept_[i]['f14'])
        F2_.append(concept_[i]['f2'])
        F160_.append(concept_[i]['f160'])
        F174_.append(concept_[i]['f174'])
        F175_.append(concept_[i]['f175'])
        F176_.append(concept_[i]['f176'])
        F177_.append(concept_[i]['f177'])
        F178_.append(concept_[i]['f178'])
        F179_.append(concept_[i]['f179'])
        F180_.append(concept_[i]['f180'])
        F181_.append(concept_[i]['f181'])
        F182_.append(concept_[i]['f182'])
        F183_.append(concept_[i]['f183'])
    Data_ = pd.DataFrame(np.transpose([F12_,F14_,F2_,F160_,F174_,F175_,F176_,F177_,F178_,F179_,F180_,F181_,F182_,F183_]),columns = Index_c)
    Data_.to_excel(r'C:\Users\NHT\Desktop\东方财富概念清单'+'\\'+str(datetime.datetime.now())[:10]+str(Data['板块编码'][k])+'-10日排行.xlsx')
    time.sleep(0.1)
    endtime_=time.time() #结束计时                                                                      
    During_= endtime_-starttime_ #计算总耗时
    print(During_)
endtime=time.time() #结束计时                                                                      
During= endtime-starttime #计算总耗时
print('数据爬取总耗时：',During,'秒')
### 构建数据
print('Finish!')
# Out:
# Concept: 海绵城市
# 0.25420141220092773
# Concept: 装配建筑
# 0.235914945602417
# Concept: 参股券商
# 0.242112398147583
# Concept: AB股
# 0.22924590110778809
# Concept: 乡村振兴
# 0.2433319091796875
# Concept: 一带一路
# 1.435589075088501
# Concept: 维生素
# 0.25153255462646484
# Concept: 水产养殖
# 0.21603035926818848
# Concept: ST股
# 0.2523763179779053
# Concept: 网红直播
# 0.26410818099975586
# Concept: 纾困概念
# 3.236262083053589
# Concept: 参股保险
# 0.2257375717163086
# Concept: B股
# 0.2563035488128662
# Concept: 碳交易
# 0.25733256340026855
# Concept: 预亏预减
# 0.22769665718078613
# Concept: 冷链物流
# 0.24563956260681152
# Concept: 中字头
# 0.2376723289489746
# Concept: 换电概念
# 0.23698878288269043
# Concept: 粤港自贸
# 0.25564074516296387
# Concept: 参股新三板
# 0.23802399635314941
# Concept: 燃料电池
# 0.2552812099456787
# Concept: 生态农业
# 0.23353862762451172
# Concept: 储能
# 0.23542571067810059
# Concept: 创投
# 0.27024221420288086
# Concept: 影视概念
# 0.22522854804992676
# Concept: 雄安新区
# 0.22833824157714844
# Concept: 土地流转
# 0.25705909729003906
# Concept: 商汤概念
# 0.21871590614318848
# Concept: 智能电视
# 0.2183384895324707
# Concept: PPP模式
# 0.23693537712097168
# Concept: 风能
# 0.24555516242980957
# Concept: 海洋经济
# 0.24836325645446777
# Concept: 油气设服
# 0.24498796463012695
# Concept: 彩票概念
# 0.24642300605773926
# Concept: 北京冬奥
# 0.24350476264953613
# Concept: 债转股
# 0.3719675540924072
# Concept: 工业大麻
# 0.24235129356384277
# Concept: 广电
# 0.22539806365966797
# Concept: 新能源
# 0.2273237705230713
# Concept: 独家药品
# 0.22929859161376953
# Concept: 拼多多概念
# 0.22923612594604492
# Concept: 体育产业
# 0.23956894874572754
# Concept: 国企改革
# 0.2366487979888916
# Concept: 元宇宙概念
# 0.2753000259399414
# Concept: 华为昇腾
# 0.21864080429077148
# Concept: 昨日连板
# 0.2306532859802246
# Concept: 昨日涨停
# 0.26603221893310547
# Concept: 转基因
# 0.24335002899169922
# Concept: 电子车牌
# 0.3580453395843506
# Concept: 云游戏
# 0.23461222648620605
# Concept: 特高压
# 0.2303781509399414
# Concept: NFT概念
# 0.22076964378356934
# Concept: 人脑工程
# 0.21547651290893555
# Concept: RCS概念
# 1.9544262886047363
# Concept: 京津冀
# 3.2600276470184326
# Concept: 赛马概念
# 0.5680608749389648
# Concept: REITs概念
# 0.24437904357910156
# Concept: 绿色电力
# 0.26317644119262695
# Concept: 核能核电
# 0.26629018783569336
# Concept: 长寿药
# 0.2593069076538086
# Concept: 智能电网
# 0.23936223983764648
# Concept: 油价相关
# 0.2164478302001953
# Concept: 地热能
# 0.22167658805847168
# Concept: 抽水蓄能
# 0.22318744659423828
# Concept: 租售同权
# 0.22028231620788574
# 数据爬取总耗时： 146.1647584438324 秒
# Finish!

# %% [markdown]
# ## 抓取概念板块历史资金 （没改完）

# %%
# 概念子页爬虫(顺序爬取)--历史资金
## 设置请求地址
url_D = 'http://push2his.eastmoney.com/api/qt/stock/fflow/daykline/get?'
## 设置请求头
headers_1 = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36',
    'Cookie': 'qgqp_b_id=d4c7d95b9a3fea432b6afb4394d1e7cb; em_hq_fls=js; st_si=11660912221455; cowminicookie=true; intellpositionL=1215.35px; st_asi=delete; HAList=ty-90-BK0918-%u7279%u9AD8%u538B%2Cty-90-BK0958-%u865A%u62DF%u7535%u5382%2Ca-sz-301179-N%u6CFD%u5B87%2Cf-0-000012-%u56FD%u503A%u6307%u6570; cowCookie=true; intellpositionT=655px; st_pvi=54890317298070; st_sp=2021-02-13%2023%3A08%3A33; st_inirUrl=https%3A%2F%2Fwww.sogou.com%2Flink; st_sn=38; st_psi=20211216140000383-113200313002-1170878720'
}
## 设置特征列表
Index_c = ['日期','主力净流入额','主力净流入占比','超大单净流入额','超大单净流入占比','大单净流入额',
          '大单净流入占比','中单净流入额','中单净流入占比','小单净流入额','小单净流入占比']
starttime= time.time() #开始计时
## 设置传递参数
for k in range(len(Data)): 
    starttime_= time.time() #开始计时
    ## 设置记录列表
    d1 = []
    d2 = []
    d7 = []
    d6 = []
    d11 = []
    d5 = []
    d10 = []
    d4 = []
    d9 = []
    d3 = []
    d8 = []
    print('Concept:',Data['板块名称'][k])
    params_M_c = { 
        'cb': 'jQuery1123004846322315639795_1639875317253',
        'lmt': '0',
        'klt': '101',
        'fields1': 'f1,f2,f3,f7',
        'fields2': 'f51,f52,f53,f54,f55,f56,f57,f58,f59,f60,f61,f62,f63,f64,f65',
        'ut': 'b2884a393a59ad64002292a3e90d46a5',
        'secid': '90.'+str(Data['板块编码'][k]),
        '_': str(round(time.mktime(time.localtime()))) #表示当前更新时间数据
    }
    try:
        response = requests.get(url_D + urlencode(params_M_c), params=params_M_c,verify=False,headers = headers_1)
    except:
        print('爬取不到数据......')
    Length = len(params_M_c['cb'])
    json_ = json.loads('['+response.text[Length+1:-2]+']')
    concept_ = json_[0]['data']['klines']
    for i in range(len(concept_)):
        record = concept_[i].split(',')
        d1.append(record[0])
        d2.append(record[1])
        d3.append(record[2])
        d4.append(record[3])
        d5.append(record[4])
        d6.append(record[5])
        d7.append(record[6])
        d8.append(record[7])
        d9.append(record[8])
        d10.append(record[9])
        d11.append(record[10])
    Data_ = pd.DataFrame(np.transpose([d1,d2,d7,d6,d11,d5,d10,d4,d9,d3,d8]),columns = Index_c)
    Data_.to_excel(r'C:\Users\NHT\Desktop\东方财富概念清单'+'\\'+str(datetime.datetime.now())[:10]+str(Data['板块编码'][k])+'-历史资金.xlsx')
    time.sleep(0.1)
    endtime_=time.time() #结束计时                                                                      
    During_= endtime_-starttime_ #计算总耗时
    print(During_)
endtime=time.time() #结束计时                                                                      
During= endtime-starttime #计算总耗时
print('数据爬取总耗时：',During,'秒')
### 构建数据
print('Finish!')
# Out:
# Concept: 海绵城市
# 0.44107604026794434
# Concept: 装配建筑
# 0.3147706985473633
# Concept: 参股券商
# 0.8860905170440674
# Concept: AB股
# 0.7250206470489502
# Concept: 乡村振兴
# 1.5679850578308105
# Concept: 一带一路
# 9.582269430160522
# Concept: 维生素
# 3.1367368698120117
# Concept: 水产养殖
# 1.3887503147125244
# Concept: ST股
# 1.947373390197754
# Concept: 网红直播
# 0.7857837677001953
# Concept: 纾困概念
# 0.5623137950897217
# Concept: 参股保险
# 1.9879159927368164
# Concept: B股
# 1.393477201461792
# Concept: 碳交易
# 2.284775972366333
# Concept: 成渝特区
# 12.525226354598999
# Concept: 基因测序
# 0.4721245765686035
# Concept: 黄金概念
