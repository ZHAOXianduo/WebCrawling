# %%
### 导入所需的数据库
import time
import requests
import json
import jsonpath
import pymongo
import pandas as pd
import urllib
import datetime
import numpy as np
from threading import Thread
from urllib.parse import urlencode

# %%
### 导入股票列表
Stocks = pd.read_excel(r'H:\个股数据\Total_Stock.xlsx') # 获取股票代码

# %%
# 参数项
## 概念板块初始和目前页面数
i_page_c = 17
## 行业板块初始和目前页面数
i_page_i = 5

# %% [markdown]
# ### 开始爬取概念与股票

# %%
# 概念主页爬虫(顺序爬取)
## 设置请求地址
url_1 = 'http://63.push2.eastmoney.com/api/qt/clist/get?'
## 设置请求头
headers_1 = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36',
    'Cookie': 'qgqp_b_id=d4c7d95b9a3fea432b6afb4394d1e7cb; em_hq_fls=js; st_si=11660912221455; cowminicookie=true; intellpositionL=1215.35px; st_asi=delete; HAList=ty-90-BK0918-%u7279%u9AD8%u538B%2Cty-90-BK0958-%u865A%u62DF%u7535%u5382%2Ca-sz-301179-N%u6CFD%u5B87%2Cf-0-000012-%u56FD%u503A%u6307%u6570; cowCookie=true; intellpositionT=655px; st_pvi=54890317298070; st_sp=2021-02-13%2023%3A08%3A33; st_inirUrl=https%3A%2F%2Fwww.sogou.com%2Flink; st_sn=38; st_psi=20211216140000383-113200313002-1170878720'
}
## 设置记录列表
F12_ = []
F14_ = []
F2_  = []
F4_  = []
F3_  = []
F7_  = []
F20_ = []
F21_ = []
F8_  = []
F104_= []
F105_= []
F10_ = []
F17_ = []
F18_ = []
F15_ = []
F16_ = []
F62_ = []
F128_= []
F140_= []
F136_= []
F207_= []
F208_= []
F222_= []
## 设置特征列表
Index_c = ['板块编码','板块名称','板块最新价','板块涨跌额','板块涨跌幅','板块振幅','板块总市值','板块流通市值','板块换手率','上涨家数','下跌家数量','板块量比','板块今开','板块昨收','板块最高','板块最低','板块主力净流入','领涨股票','领涨股票编码','领涨股票涨幅','领跌股票','领跌股票编码','领跌股票涨幅']
starttime= time.time() #开始计时
## 设置传递参数
for k in range(i_page_c):
    print('Page:',k+1)
    if response.status_code != 200:
        print('爬取有误')
    params_M_c = {
        'cb': 'jQuery1124018456954517801738_1639634362993',
        'pn': str(k+1), #修改pn能够得到下一页
        'pz': '20',
        'po': '1',
        'np': '1',
        'ut': 'bd1d9ddb04089700cf9c27f6f7426281',
        'fltt': '2',
        'invt': '2',
        'fid': 'f3',
        'fs': 'm:90 t:3 f:!50',
        'fields': 'f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f12,f13,f14,f15,f16,f17,f18,f20,f21,f23,f24,f25,f26,f22,f33,f11,f62,f128,f136,f115,f152,f124,f107,f104,f105,f140,f141,f207,f208,f209,f222',
        '_': '1639634363007'
    }
    response = requests.get(url_1 + urlencode(params_M_c), params=params_M_c,verify=False,headers = headers_1)
    Length = len(params_M_c['cb'])
    json_ = json.loads('['+response.text[Length+1:-2]+']')
    concept_ = json_[0]['data']['diff']
    for i in range(len(concept_)):
        F12_.append(concept_[i]['f12'])
        F14_.append(concept_[i]['f14'])
        F2_.append(concept_[i]['f2'])
        F4_.append(concept_[i]['f4'])
        F3_.append(concept_[i]['f3'])
        F7_.append(concept_[i]['f7'])
        F20_.append(concept_[i]['f20'])
        F21_.append(concept_[i]['f21'])
        F8_.append(concept_[i]['f8'])
        F104_.append(concept_[i]['f104'])
        F105_.append(concept_[i]['f105'])
        F10_.append(concept_[i]['f10'])
        F17_.append(concept_[i]['f17'])
        F18_.append(concept_[i]['f18'])
        F15_.append(concept_[i]['f15'])
        F16_.append(concept_[i]['f16'])
        F62_.append(concept_[i]['f62'])
        F128_.append(concept_[i]['f128'])
        F140_.append(concept_[i]['f140'])
        F136_.append(concept_[i]['f136'])
        F207_.append(concept_[i]['f207'])
        F208_.append(concept_[i]['f208'])
        F222_.append(concept_[i]['f222'])
endtime=time.time() #结束计时                                                                      
During= endtime-starttime #计算总耗时
print('数据爬取总耗时：',During,'秒')
### 构建数据
Data = pd.DataFrame(np.transpose([F12_,F14_,F2_,F4_,F3_,F7_,F20_,F21_,F8_,F104_,F105_,F10_,F17_,F18_,F15_,F16_,F62_,F128_,F140_,F136_,F207_,F208_,F222_]),columns = Index_c)
Data.to_excel(r'C:\Users\NHT\Desktop\东方财富板块数据'+str(datetime.datetime.now())[:10]+'.xlsx')
print('Finish!')
# Out:
# Page: 1
# Page: 2
# Page: 3
# Page: 4
# Page: 5
# Page: 6
# Page: 7
# Page: 8
# Page: 9
# Page: 10
# Page: 11
# Page: 12
# Page: 13
# Page: 14
# Page: 15
# Page: 16
# Page: 17
# 数据爬取总耗时： 38.08796429634094 秒
# Finish!

# %%
# 概念主页爬虫(多线程抓取)

## 设置请求地址
url_1 = 'http://63.push2.eastmoney.com/api/qt/clist/get?'
## 设置请求头
headers_1 = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36',
    'Cookie': 'qgqp_b_id=d4c7d95b9a3fea432b6afb4394d1e7cb; em_hq_fls=js; st_si=11660912221455; cowminicookie=true; intellpositionL=1215.35px; st_asi=delete; HAList=ty-90-BK0918-%u7279%u9AD8%u538B%2Cty-90-BK0958-%u865A%u62DF%u7535%u5382%2Ca-sz-301179-N%u6CFD%u5B87%2Cf-0-000012-%u56FD%u503A%u6307%u6570; cowCookie=true; intellpositionT=655px; st_pvi=54890317298070; st_sp=2021-02-13%2023%3A08%3A33; st_inirUrl=https%3A%2F%2Fwww.sogou.com%2Flink; st_sn=38; st_psi=20211216140000383-113200313002-1170878720'
}
## 设置记录列表
F12_ = []
F14_ = []
F2_  = []
F4_  = []
F3_  = []
F7_  = []
F20_ = []
F21_ = []
F8_  = []
F104_= []
F105_= []
F10_ = []
F17_ = []
F18_ = []
F15_ = []
F16_ = []
F62_ = []
F128_= []
F140_= []
F136_= []
F207_= []
F208_= []
F222_= []
## 设置特征列表
Index_c = ['板块编码','板块名称','板块最新价','板块涨跌额','板块涨跌幅','板块振幅','板块总市值','板块流通市值','板块换手率','上涨家数','下跌家数量','板块量比','板块今开','板块昨收','板块最高','板块最低','板块主力净流入','领涨股票','领涨股票编码','领涨股票涨幅','领跌股票','领跌股票编码','领跌股票涨幅']
def thread():   
    def get_params(k):
        params_M_c = {
        'cb': 'jQuery1124018456954517801738_1639634362993',
        'pn': str(k+1), #修改pn能够得到下一页
        'pz': '20',
        'po': '1',
        'np': '1',
        'ut': 'bd1d9ddb04089700cf9c27f6f7426281',
        'fltt': '2',
        'invt': '2',
        'fid': 'f3',
        'fs': 'm:90 t:3 f:!50',
        'fields': 'f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f12,f13,f14,f15,f16,f17,f18,f20,f21,f23,f24,f25,f26,f22,f33,f11,f62,f128,f136,f115,f152,f124,f107,f104,f105,f140,f141,f207,f208,f209,f222',
        '_': '1639634363007'
        }
        response = requests.get(url_1 + urlencode(params_M_c), params=params_M_c,verify=False,headers = headers_1)
        Length = len(params_M_c['cb'])
        json_ = json.loads('['+response.text[Length+1:-2]+']')
        concept_ = json_[0]['data']['diff']
        for i in range(len(concept_)):
            F12_.append(concept_[i]['f12'])
            F14_.append(concept_[i]['f14'])
            F2_.append(concept_[i]['f2'])
            F4_.append(concept_[i]['f4'])
            F3_.append(concept_[i]['f3'])
            F7_.append(concept_[i]['f7'])
            F20_.append(concept_[i]['f20'])
            F21_.append(concept_[i]['f21'])
            F8_.append(concept_[i]['f8'])
            F104_.append(concept_[i]['f104'])
            F105_.append(concept_[i]['f105'])
            F10_.append(concept_[i]['f10'])
            F17_.append(concept_[i]['f17'])
            F18_.append(concept_[i]['f18'])
            F15_.append(concept_[i]['f15'])
            F16_.append(concept_[i]['f16'])
            F62_.append(concept_[i]['f62'])
            F128_.append(concept_[i]['f128'])
            F140_.append(concept_[i]['f140'])
            F136_.append(concept_[i]['f136'])
            F207_.append(concept_[i]['f207'])
            F208_.append(concept_[i]['f208'])
            F222_.append(concept_[i]['f222'])
    print(u'多线程抓取')                                                                                        
    ts = [Thread(target=get_params, args=(k,)) for k in range(i_page_c)]                                                 
    starttime= time.time()                                                                                 
    for t in ts:                                                                                           
        t.start()                                                                                          
    for t in ts:                                                                                           
        t.join()                                                                                           
    endtime=time.time()                                                                                    
    print('数据爬取总耗时：',endtime-starttime)
thread()
### 构建数据
Data = pd.DataFrame(np.transpose([F12_,F14_,F2_,F4_,F3_,F7_,F20_,F21_,F8_,F104_,F105_,F10_,F17_,F18_,F15_,F16_,F62_,F128_,F140_,F136_,F207_,F208_,F222_]),columns = Index_c)
#Data.to_excel(r'C:\Users\NHT\Desktop\东方财富板块数据'+str(datetime.datetime.now())[:10]+'.xlsx')
print('Finish!')
# Out:
# 多线程抓取
# 数据爬取总耗时： 0.15296053886413574
# Finish!

# %%
Data['板块编码']
# Out:
# 0      BK0843
# 1      BK0700
# 2      BK0888
# 3      BK0928
# 4      BK0818
#         ...
# 329    BK0957
# 330    BK0708
# 331    BK0683
# 332    BK1009
# 333    BK0995
# Name: 板块编码, Length: 334, dtype: object

# %%
Data
# Out:
#        板块编码  板块名称     板块最新价    板块涨跌额  板块涨跌幅  板块振幅          板块总市值  \
# 0    BK0816  昨日连板   1120.18    48.16   4.49  2.11   295153280000
# 1    BK0815  昨日涨停  49334.58  1054.07   2.18   1.4   983590080000
# 2    BK0907   转基因   1805.04    26.14   1.47  2.85   178543457000
# 3    BK0982  电子车牌   1005.19    13.62   1.37  2.49   184897638000
# 4    BK0903   云游戏   1198.16    15.99   1.35  4.08   374532912000
# ..      ...   ...       ...      ...    ...   ...            ...
# 329  BK1010   磷化工    819.68   -13.78  -1.65  2.14   604500064000
# 330  BK0512  化工原料  23628.34  -397.23  -1.65  1.68  1509060624000
# 331  BK1005  专精特新   1031.79   -17.52  -1.67  1.44  3440365168000
# 332  BK0840  OLED   2295.03   -39.04  -1.67   1.5  2260049696000
# 333  BK0723   高送转    3699.4   -63.52  -1.69   1.5  2213188384000
#
#             板块流通市值  板块换手率 上涨家数  ...      板块昨收      板块最高      板块最低  \
# 0     223371153000  17.38   18  ...   1072.02   1133.34   1110.77
# 1     750609648000   8.65   50  ...  48280.51  50007.31  49331.75
# 2     147810902000   4.13    9  ...    1778.9   1817.64   1766.91
# 3     141945524000   4.61    6  ...    991.57   1008.36    983.63
# 4     310001072000    8.8   14  ...   1182.17   1215.07   1166.84
# ..             ...    ...  ...  ...       ...       ...       ...
# 329   499725376000    2.4    8  ...    833.46    837.44    819.64
# 330  1163763008000   1.98   10  ...  24025.57  24029.62  23626.35
# 331  2136749312000   3.28   72  ...   1049.31   1046.88   1031.79
# 332  1883295600000   1.99   20  ...   2334.07   2328.52   2293.62
# 333  1610009328000   1.81   23  ...   3762.92   3755.91    3699.4
#
#            板块主力净流入  领涨股票  领涨股票编码 领涨股票涨幅  领跌股票  领跌股票编码  领跌股票涨幅
# 0    -1134438704.0  兰石重装  603169   9.99  重庆建工  600939    -6.5
# 1    -5300664576.0  靖远煤电  000552   9.94  泰林生物  300813  -11.73
# 2      173338928.0  万向德农  600371  10.02  新安股份  600596   -2.08
# 3     -122054496.0  经纬辉开  300120  20.02  大华股份  002236   -4.96
# 4      357291504.0   汤姆猫  300459   17.5   新国脉  600640   -3.95
# ..             ...   ...     ...    ...   ...     ...     ...
# 329  -1407745936.0  罗平锌电  002114   2.96  阳煤化工  600691   -6.35
# 330  -2429165440.0  滨化股份  601678    4.2  隆华新材  301149   -5.33
# 331  -3155054304.0  尚纬股份  603333   9.99  帝科股份  300842   -8.43
# 332  -3659239424.0  经纬辉开  300120  20.02  北京君正  300223   -7.04
# 333  -1486143632.0  同和药业  300636   9.18  锦浪科技  300763   -7.68
#
# [334 rows x 23 columns]

# %%
# 概念主页爬虫(多线程抓取)
def thread():   
    ## 设置请求地址
    url_1 = 'http://63.push2.eastmoney.com/api/qt/clist/get?'
    ## 设置请求头
    headers_1 = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36',
        'Cookie': 'qgqp_b_id=d4c7d95b9a3fea432b6afb4394d1e7cb; em_hq_fls=js; st_si=11660912221455; cowminicookie=true; intellpositionL=1215.35px; st_asi=delete; HAList=ty-90-BK0918-%u7279%u9AD8%u538B%2Cty-90-BK0958-%u865A%u62DF%u7535%u5382%2Ca-sz-301179-N%u6CFD%u5B87%2Cf-0-000012-%u56FD%u503A%u6307%u6570; cowCookie=true; intellpositionT=655px; st_pvi=54890317298070; st_sp=2021-02-13%2023%3A08%3A33; st_inirUrl=https%3A%2F%2Fwww.sogou.com%2Flink; st_sn=38; st_psi=20211216140000383-113200313002-1170878720'
    }
    ## 设置记录列表
    F12_ = []
    F14_ = []
    F2_  = []
    F4_  = []
    F3_  = []
    F7_  = []
    F20_ = []
    F21_ = []
    F8_  = []
    F104_= []
    F105_= []
    F10_ = []
    F17_ = []
    F18_ = []
    F15_ = []
    F16_ = []
    F62_ = []
    F128_= []
    F140_= []
    F136_= []
    F207_= []
    F208_= []
    F222_= []
    ## 设置特征列表
    Index_c = ['板块编码','板块名称','板块最新价','板块涨跌额','板块涨跌幅','板块振幅','板块总市值','板块流通市值','板块换手率','上涨家数','下跌家数量','板块量比','板块今开','板块昨收','板块最高','板块最低','板块主力净流入','领涨股票','领涨股票编码','领涨股票涨幅','领跌股票','领跌股票编码','领跌股票涨幅']
    def get_params(k):
        params_M_c = {
        'cb': 'jQuery1124018456954517801738_1639634362993',
        'pn': str(k+1), #修改pn能够得到下一页
        'pz': '20',
        'po': '1',
        'np': '1',
        'ut': 'bd1d9ddb04089700cf9c27f6f7426281',
        'fltt': '2',
        'invt': '2',
        'fid': 'f3',
        'fs': 'm:90 t:3 f:!50',
        'fields': 'f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f12,f13,f14,f15,f16,f17,f18,f20,f21,f23,f24,f25,f26,f22,f33,f11,f62,f128,f136,f115,f152,f124,f107,f104,f105,f140,f141,f207,f208,f209,f222',
        '_': '1639634363007'
        }
        response = requests.get(url_1 + urlencode(params_M_c), params=params_M_c,verify=False,headers = headers_1)
        Length = len(params_M_c['cb'])
        json_ = json.loads('['+response.text[Length+1:-2]+']')
        concept_ = json_[0]['data']['diff']
        for i in range(len(concept_)):
            F12_.append(concept_[i]['f12'])
            F14_.append(concept_[i]['f14'])
            F2_.append(concept_[i]['f2'])
            F4_.append(concept_[i]['f4'])
            F3_.append(concept_[i]['f3'])
            F7_.append(concept_[i]['f7'])
            F20_.append(concept_[i]['f20'])
            F21_.append(concept_[i]['f21'])
            F8_.append(concept_[i]['f8'])
            F104_.append(concept_[i]['f104'])
            F105_.append(concept_[i]['f105'])
            F10_.append(concept_[i]['f10'])
            F17_.append(concept_[i]['f17'])
            F18_.append(concept_[i]['f18'])
            F15_.append(concept_[i]['f15'])
            F16_.append(concept_[i]['f16'])
            F62_.append(concept_[i]['f62'])
            F128_.append(concept_[i]['f128'])
            F140_.append(concept_[i]['f140'])
            F136_.append(concept_[i]['f136'])
            F207_.append(concept_[i]['f207'])
            F208_.append(concept_[i]['f208'])
            F222_.append(concept_[i]['f222'])
    print(u'多线程抓取')                                                                                        
    ts = [Thread(target=get_params, args=(k,)) for k in range(i_page_c)]                                                 
    starttime= time.time()                                                                                 
    for t in ts:                                                                                           
        t.start()                                                                                          
    for t in ts:                                                                                           
        t.join()                                                                                           
    endtime=time.time()                                                                                    
    print('数据爬取总耗时：',endtime-starttime)
thread()
### 构建数据
Data = pd.DataFrame(np.transpose([F12_,F14_,F2_,F4_,F3_,F7_,F20_,F21_,F8_,F104_,F105_,F10_,F17_,F18_,F15_,F16_,F62_,F128_,F140_,F136_,F207_,F208_,F222_]),columns = Index_c)
Data.to_excel(r'C:\Users\NHT\Desktop\东方财富板块数据'+str(datetime.datetime.now())[:10]+'.xlsx')
print('Finish!')
# Out:
# 多线程抓取
# 数据爬取总耗时： 3.2522919178009033
# F:\Download\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# F:\Download\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1661                 blocks = [
# -> 1662                     make_block(values=blocks[0], placement=slice(0, len(axes[0])))
#    1663                 ]
#
# F:\Download\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2721
# -> 2722     return klass(values, ndim=ndim, placement=placement)
#    2723
#
# F:\Download\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#    2377
# -> 2378         super().__init__(values, ndim=ndim, placement=placement)
#    2379
#
# F:\Download\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     129         if self._validate_ndim and self.ndim and len(self.mgr_locs) != len(self.values):
# --> 130             raise ValueError(
#     131                 f"Wrong number of items passed {len(self.values)}, "
#
# ValueError: Wrong number of items passed 1, placement implies 14
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-7a2d61f01a38> in <module>
#      88 thread()
#      89 ### 构建数据
# ---> 90 Data = pd.DataFrame(np.transpose([F12_,F14_,F2_,F4_,F3_,F7_,F20_,F21_,F8_,F104_,F105_,F10_,F17_,F18_,F15_,F16_,F62_,F128_,F140_,F136_,F207_,F208_,F222_]),columns = Index_c)
#      91 Data.to_excel(r'C:\Users\NHT\Desktop\东方财富板块数据'+str(datetime.datetime.now())[:10]+'.xlsx')
#      92 print('Finish!')
#
# F:\Download\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     495                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     496             else:
# --> 497                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     498
#     499         # For data is list-like, or Iterable (will consume into list)
#
# F:\Download\lib\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     232         block_values = [values]
#     233
# --> 234     return create_block_manager_from_blocks(block_values, [columns, index])
#     235
#     236
#
# F:\Download\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1670         blocks = [getattr(b, "values", b) for b in blocks]
#    1671         tot_items = sum(b.shape[0] for b in blocks)
# -> 1672         raise construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    1673
#    1674
#
# ValueError: Shape of passed values is (23, 1), indices imply (23, 14)

# %%
# 概念主页爬虫(顺序爬取)
## 设置请求地址
url_D = 'http://push2.eastmoney.com/api/qt/clist/get?'
## 设置请求头
headers_1 = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36',
    'Cookie': 'qgqp_b_id=d4c7d95b9a3fea432b6afb4394d1e7cb; em_hq_fls=js; st_si=11660912221455; cowminicookie=true; intellpositionL=1215.35px; st_asi=delete; HAList=ty-90-BK0918-%u7279%u9AD8%u538B%2Cty-90-BK0958-%u865A%u62DF%u7535%u5382%2Ca-sz-301179-N%u6CFD%u5B87%2Cf-0-000012-%u56FD%u503A%u6307%u6570; cowCookie=true; intellpositionT=655px; st_pvi=54890317298070; st_sp=2021-02-13%2023%3A08%3A33; st_inirUrl=https%3A%2F%2Fwww.sogou.com%2Flink; st_sn=38; st_psi=20211216140000383-113200313002-1170878720'
}
## 设置特征列表
Index_c = ['代码','名称','最新价','涨跌幅','主力净流入额','主力净流入占比','超大单净流入额','超大单净流入占比','大单净流入额',
          '大单净流入额','大单净流入占比','中单净流入占比','小单净流入额','小单净流入占比']
starttime= time.time() #开始计时
## 设置传递参数
for k in range(len(Data)): 
    starttime_= time.time() #开始计时
    ## 设置记录列表
    F12_ = []
    F14_ = []
    F2_  = []
    F3_  = []
    F62_ = []
    F184_= []
    F66_ = []
    F69_ = []
    F72_ = []
    F75_ = []
    F78_ = []
    F81_ = []
    F84_ = []
    F87_ = []
    print('Concept:',Data['板块名称'][k])
    params_M_c = {
        'cb': 'jQuery112306861266349057402_1639874233876',
        'fid': 'f62', #涉及抽取的表格
        'po': '1',
        'pz': '50',
        'pn': '1',
        'np': '1',
        'fltt': '2',
        'invt': '2',
        'ut': 'b2884a393a59ad64002292a3e90d46a5',
        'fs': 'b:'+str(Data['板块编码'][k]), #涉及抽取的行业/概念
        'fields': 'f12,f14,f2,f3,f62,f184,f66,f69,f72,f75,f78,f81,f84,f87,f204,f205,f124,f1,f13' #涉及抽取的表格的数据
    }
    try:
        response = requests.get(url_D + urlencode(params_M_c), params=params_M_c,verify=False,headers = headers_1)
    except:
        print('爬取不到数据......')
    Length = len(params_M_c['cb'])
    json_ = json.loads('['+response.text[Length+1:-2]+']')
    concept_ = json_[0]['data']['diff']
    for i in range(len(concept_)):
        F12_.append(concept_[i]['f12'])
        F14_.append(concept_[i]['f14'])
        F2_.append(concept_[i]['f2'])
        F3_.append(concept_[i]['f3'])
        F62_.append(concept_[i]['f62'])
        F184_.append(concept_[i]['f184'])
        F66_.append(concept_[i]['f66'])
        F69_.append(concept_[i]['f69'])
        F72_.append(concept_[i]['f72'])
        F75_.append(concept_[i]['f75'])
        F78_.append(concept_[i]['f78'])
        F81_.append(concept_[i]['f81'])
        F84_.append(concept_[i]['f84'])
        F87_.append(concept_[i]['f87'])
    Data_ = pd.DataFrame(np.transpose([F12_,F14_,F2_,F3_,F62_,F184_,F66_,F69_,F72_,F75_,F78_,F81_,F84_,F87_]),columns = Index_c)
    #Data_.to_excel(r'C:\Users\NHT\Desktop'+'\\'+str(datetime.datetime.now())[:10]+str(Data['板块编码'][k])+'-今日排行.xlsx')
    time.sleep(0.1)
    endtime_=time.time() #结束计时                                                                      
    During_= endtime_-starttime_ #计算总耗时
    print(During_)
endtime=time.time() #结束计时                                                                      
During= endtime-starttime #计算总耗时
print('数据爬取总耗时：',During,'秒')
### 构建数据
print('Finish!')
# Out:
# Concept: 1
# Concept: 2
# Concept: 3
# Concept: 4
# Concept: 5
# Concept: 6
# Concept: 7
# Concept: 8
# Concept: 9
# Concept: 10
# Concept: 11
# Concept: 12
# Concept: 13
# Concept: 14
# Concept: 15
# Concept: 16
# Concept: 17
# Concept: 18
# Concept: 19
# Concept: 20
# Concept: 21
# Concept: 22
# Concept: 23
# Concept: 24
# Concept: 25
# Concept: 26
# Concept: 27
# Concept: 28
# Concept: 29
# Concept: 30
# Concept: 31
# Concept: 32
# Concept: 33
# Concept: 34
# Concept: 35
# Concept: 36
# Concept: 37
# Concept: 38
# Concept: 39
# Concept: 40
# Concept: 41
# Concept: 42
# Concept: 43
# Concept: 44
# Concept: 45
# Concept: 46
# Concept: 47
# Concept: 48
# Concept: 49
# Concept: 50
# Concept: 51
# Concept: 52
# Concept: 53
# Concept: 54
# Concept: 55
# Concept: 56
# Concept: 57
# Concept: 58
# Concept: 59
# Concept: 60
# Concept: 61
# Concept: 62
# Concept: 63
# Concept: 64
# Concept: 65
# Concept: 66
# Concept: 67
# Concept: 68
# Concept: 69
# Concept: 70
# Concept: 71
# Concept: 72
# Concept: 73
# Concept: 74
# Concept: 75
# Concept: 76
# Concept: 77
# Concept: 78
# Concept: 79
# Concept: 80
# Concept: 81
# Concept: 82
# Concept: 83
# Concept: 84
# Concept: 85
# Concept: 86
# Concept: 87
# Concept: 88
# Concept: 89
# Concept: 90
# Concept: 91
# Concept: 92
# Concept: 93
# Concept: 94
# Concept: 95
# Concept: 96
# Concept: 97
# Concept: 98
# Concept: 99
# Concept: 100
# Concept: 101
# Concept: 102
# Concept: 103
# Concept: 104
# Concept: 105
# Concept: 106
# Concept: 107
# Concept: 108
# Concept: 109
# Concept: 110
# Concept: 111
# Concept: 112
# Concept: 113
# Concept: 114
# Concept: 115
# Concept: 116
# Concept: 117
# Concept: 118
# Concept: 119
# Concept: 120
# Concept: 121
# Concept: 122
# Concept: 123
# Concept: 124
# Concept: 125
# Concept: 126
# Concept: 127
# Concept: 128
# Concept: 129
# Concept: 130
# Concept: 131
# Concept: 132
# Concept: 133
# Concept: 134
# Concept: 135
# Concept: 136
# Concept: 137
# Concept: 138
# Concept: 139
# Concept: 140
# Concept: 141
# Concept: 142
# Concept: 143
# Concept: 144
# Concept: 145
# Concept: 146
# Concept: 147
# Concept: 148
# Concept: 149
# Concept: 150
# Concept: 151
# Concept: 152
# Concept: 153
# Concept: 154
# Concept: 155
# Concept: 156
# Concept: 157
# Concept: 158
# Concept: 159
# Concept: 160
# Concept: 161

# %%
Data['板块名称'][312]
# Out:
# 'MLCC'
