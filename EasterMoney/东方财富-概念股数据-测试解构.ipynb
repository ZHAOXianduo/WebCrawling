# %% [markdown]
# ### 概念主页：
# ### http://quote.eastmoney.com/center/boardlist.html#concept_board
#
# #### 概念子页：
# #### http://quote.eastmoney.com/bk/90.BK0958.html
# #### Note1： BK0958是概念编码，通过修改概念编码获得不同概念子页
# #### Note2：概念编码通过解析主页可以得到
#
# #### 概念资金流子页
# #### http://data.eastmoney.com/bkzj/BK0958.html
# #### Note1： BK0958是概念编码，通过修改概念编码获得不同概念子页

# %%
# Loading Library
import time
import requests
import json
import jsonpath
import pymongo
import pandas as pd
import urllib
#from bs4 import BeautifulSoup
from openpyxl import load_workbook
from urllib.parse import urlencode

# %%
# 参数项
## 概念板块初始和目前页面数
i_page_c = 17
## 行业板块初始和目前页面数
i_page_i = 5

# %%
# 概念主页爬虫测试项
## 设置请求地址
url_1 = 'http://63.push2.eastmoney.com/api/qt/clist/get?'
## 设置请求头
headers_1 = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36',
    'Cookie': 'qgqp_b_id=d4c7d95b9a3fea432b6afb4394d1e7cb; em_hq_fls=js; st_si=11660912221455; cowminicookie=true; intellpositionL=1215.35px; st_asi=delete; HAList=ty-90-BK0918-%u7279%u9AD8%u538B%2Cty-90-BK0958-%u865A%u62DF%u7535%u5382%2Ca-sz-301179-N%u6CFD%u5B87%2Cf-0-000012-%u56FD%u503A%u6307%u6570; cowCookie=true; intellpositionT=655px; st_pvi=54890317298070; st_sp=2021-02-13%2023%3A08%3A33; st_inirUrl=https%3A%2F%2Fwww.sogou.com%2Flink; st_sn=38; st_psi=20211216140000383-113200313002-1170878720'
}
## 设置传递参数
params_1 = {
    'cb': 'jQuery1124018456954517801738_1639634362993',
    'pn': '1', #修改pn能够得到下一页
    'pz': '20',
    'po': '1',
    'np': '1',
    'ut': 'bd1d9ddb04089700cf9c27f6f7426281',
    'fltt': '2',
    'invt': '2',
    'fid': 'f3',
    'fs': 'm:90 t:3 f:!50',
    'fields': 'f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f12,f13,f14,f15,f16,f17,f18,f20,f21,f23,f24,f25,f26,f22,f33,f11,f62,f128,f136,f115,f152,f124,f107,f104,f105,f140,f141,f207,f208,f209,f222',
    '_': '1639634363007'
}

# %%
## 记录请求时间
starttime= time.time() 
response = requests.get(url_1 + urlencode(params_1), params=params_1,verify=False,headers = headers_1)
endtime=time.time()                                                                       
print(endtime-starttime)
# Out:
# 1.4935474395751953

# %%
# response.text

# %%
Length = len(params_1['cb'])

# %%
json_1_1 = json.loads('['+response.text[Length+1:-2]+']')

# %%
#json_1_1[0]['data']['diff'][0]['']
## 第二个0表示表格的行数，修正为i in range(20)
## 最后一个索引检索每一行表格中每一列元素，下面对元素对应的标记做一下说明
## f1
## f2
## f3
## f4...

# %%
concept = json_1_1[0]['data']['diff']
for i in range(len(concept)):
    #print(concept[i]['f14'])
    print(concept[i])
# Out:
# {'f1': 2, 'f2': 1120.18, 'f3': 4.49, 'f4': 48.16, 'f5': 19038943, 'f6': 20681457664.0, 'f7': 2.11, 'f8': 17.38, 'f9': 16.01, 'f10': 2.13, 'f11': -0.08, 'f12': 'BK0816', 'f13': 90, 'f14': '昨日连板', 'f15': 1133.34, 'f16': 1110.77, 'f17': 1113.48, 'f18': 1072.02, 'f20': 295153280000, 'f21': 223371153000, 'f22': 0.0, 'f23': '-', 'f24': 251.08, 'f25': -90.32, 'f26': '-', 'f33': 0.0, 'f62': -1134438704.0, 'f104': 18, 'f105': 6, 'f107': 5, 'f115': '-', 'f124': 1639726802, 'f128': '兰石重装', 'f140': '603169', 'f141': 1, 'f136': 9.99, 'f152': 2, 'f207': '重庆建工', 'f208': '600939', 'f209': 1, 'f222': -6.5}
# ...

# %%
# 概念主页爬虫测试项
## 设置请求地址
url_1 = 'http://push2his.eastmoney.com/api/qt/stock/fflow/daykline/get?'
## 设置请求头
headers_1 = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36',
    'Cookie': 'qgqp_b_id=d4c7d95b9a3fea432b6afb4394d1e7cb; em_hq_fls=js; st_si=11660912221455; cowminicookie=true; intellpositionL=1215.35px; st_asi=delete; HAList=ty-90-BK0918-%u7279%u9AD8%u538B%2Cty-90-BK0958-%u865A%u62DF%u7535%u5382%2Ca-sz-301179-N%u6CFD%u5B87%2Cf-0-000012-%u56FD%u503A%u6307%u6570; cowCookie=true; intellpositionT=1414.2px; has_jump_to_web=1; st_pvi=54890317298070; st_sp=2021-02-13%2023%3A08%3A33; st_inirUrl=https%3A%2F%2Fwww.sogou.com%2Flink; st_sn=48; st_psi=20211216161929411-113300300992-4721075186'
}
## 设置传递参数
params_1 = {
    'cb': 'jQuery1123004846322315639795_1639875317253',
    'lmt': '0',
    'klt': '101',
    'fields1': 'f1,f2,f3,f7',
    'fields2': 'f51,f52,f53,f54,f55,f56,f57,f58,f59,f60,f61,f62,f63,f64,f65',
    'ut': 'b2884a393a59ad64002292a3e90d46a5',
    'secid': '90.BK0816',
    '_': '1639875317254'
}

# %%
## 记录请求时间
starttime= time.time() 
response = requests.get(url_1 + urlencode(params_1), params=params_1,verify=False,headers = headers_1)
endtime=time.time()                                                                       
print(endtime-starttime)
# Out:
# 0.4080948829650879

# %%
Length = len(params_1['cb'])

# %%
json_ = json.loads('['+response.text[Length+1:-2]+']')
json_[0]['data']['klines'][0].split(',')
# Out:
# ['2021-07-21',
#  '-337229680.0',
#  '332063632.0',
#  '5166048.0',
#  '-261313328.0',
#  '-75916352.0',
#  '-6.95',
#  '6.85',
#  '0.11',
#  '-5.39',
#  '-1.57',
#  '122.49',
#  '3.52',
#  '0.00',
#  '0.00']

# %%
json_
# Out:
# [{'rc': 0,
#   'rt': 6,
#   'svr': 2887259304,
#   'lt': 2,
#   'full': 1,
#   'data': {'total': 24,
#    'diff': [{'f1': 2,
#      'f2': 7.29,
#      'f12': '601700',
#      'f13': 1,
#      'f14': '风范股份',
#      'f109': 60.93,
#      'f124': 1639727999,
#      'f164': 273061463.0,
#      'f165': 11.65,
#      'f166': 254003382.0,
#      'f167': 10.84,
#      'f168': 19058081.0,
#      'f169': 0.81,
#      'f170': -138070007.0,
#      'f171': -5.89,
#      'f172': -134991456.0,
#      'f173': -5.76,
#      'f257': '-',
#      'f258': '-',
#      'f259': '-'},
#     {'f1': 2,
#      'f2': 7.37,
#      'f12': '601068',
#      'f13': 1,
#      'f14': '中铝国际',
#      'f109': 60.92,
#      'f124': 1639727987,
#      'f164': 126073132.0,
#      'f165': 4.59,
#      'f166': 221717633.0,
#      'f167': 8.07,
#      'f168': -95644501.0,
#      'f169': -3.48,
#      'f170': -91213591.0,
#      'f171': -3.32,
#      'f172': -34859523.0,
#      'f173': -1.27,
#      'f257': '-',
# ...

# %% [markdown]
# ### 行业主页：
# ### http://quote.eastmoney.com/center/boardlist.html#industry_board
#
# #### 行业子页：
# #### http://quote.eastmoney.com/bk/90.BK0428.html
# #### Note1： BK0428是行业编码，通过修改行业编码获得不同行业子页
# #### Note2：行业编码通过解析主页可以得到
#
# #### 行业资金流子页
# #### http://data.eastmoney.com/bkzj/BK0428.html
# #### Note1： BK0428是行业编码，通过修改行业编码获得不同行业子页
#
# #### 行业股吧子页
# #### http://guba.eastmoney.com/list,BK0428.html
#
# #### 行业研报子页
# #### http://data.eastmoney.com/report/428yb.html
# #### Note1： 428是行业编码后三位，通过修改行业编码获得不同行业子页

# %%
1020 % 100
# Out:
# 20
